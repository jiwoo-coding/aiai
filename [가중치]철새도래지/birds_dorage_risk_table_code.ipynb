# %%
import naverMap
import pandas as pd
import numpy as np
from tqdm import tqdm
from pandas import DataFrame

# %%
aiai=pd.read_csv("철새도래지_좌표_최종.csv", encoding='utf-8-sig')

# %%
aiai.head()
# Out:
#    index    지역 철새도래지명     시도   시군 위험분류  위험분류 점수         위도          경도  \
# 0      1  서울경기   강서지구  서울특별시  강서구  저위험        3  37.590198  126.813625
# 1      2  서울경기    중랑천  서울특별시  중랑구  중위험        2  37.603083  127.072106
# 2      3  서울경기   안양천   서울특별시  양천구  저위험        3  37.513562  126.874612
# 3      4  서울경기     탄천  서울특별시  송파구  중위험        2  37.495083  127.101506
# 4      5  서울경기   원천리천    경기도  수원시  저위험        3  37.264812  127.049762
#
#                                     위도,경도
# 0    37.5901984197481, 126.81362533492893
# 1      37.6030830331226, 127.072105737988
# 2  37.513562487735406, 126.87461172643478
# 3   37.49508293706438, 127.10150560559426
# 4   37.26481224039535, 127.04976224622416

# %%
aiai_local=pd.read_csv("전국_occur_hpai.csv", encoding='utf-8-sig')

# %%
aiai_local['주소']=aiai_local['시도']+' '+aiai_local['시군구']

# %%
aiai_local.head()
# Out:
#       시도  시군구  발생건수         주소
# 0  서울특별시  종로구     0  서울특별시 종로구
# 1  서울특별시   중구     0   서울특별시 중구
# 2  서울특별시  용산구     0  서울특별시 용산구
# 3  서울특별시  성동구     0  서울특별시 성동구
# 4  서울특별시  광진구     2  서울특별시 광진구

# %%
aiai_local['주소']
# Out:
# 0         서울특별시 종로구
# 1          서울특별시 중구
# 2         서울특별시 용산구
# 3         서울특별시 성동구
# 4         서울특별시 광진구
#            ...
# 224        경상남도 함양군
# 225        경상남도 거창군
# 226        경상남도 합천군
# 227     제주특별자치도 제주시
# 228    제주특별자치도 서귀포시
# Name: 주소, Length: 229, dtype: object

# %%
aiai['위험분류 점수']=aiai['위험분류 점수'].astype('str')

# %%
#aiai_local2=pd.DataFrame(columns=['주소']+list(aiai['철새도래지명']+" ,"+aiai['위도,경도']))

# %%
aiai_local2=pd.DataFrame(columns=['주소']+list(aiai['철새도래지명']+" "+aiai['위험분류 점수']+','+aiai['위도,경도']))

# %%
aiai_local2.head()
# Out:
# Empty DataFrame
# Columns: [주소, 강서지구 3,37.5901984197481, 126.81362533492893, 중랑천 2,37.6030830331226, 127.072105737988, 안양천  3,37.513562487735406, 126.87461172643478, 탄천 2,37.49508293706438, 127.10150560559426, 원천리천 3,37.26481224039535, 127.04976224622416, 서호 3,37.280408134249136, 126.98755251443214, 안성천 1,36.99139105195746, 127.20539544460591, 경안천 2,37.309938272435886, 127.23553552424399, 상패천 2,37.91927602221171, 127.05389142205611, 왕송호수 3,37.30748917786908, 126.94731063485848, 황구지천 2,37.20796105720859, 127.02548060229643, 문산천 2,37.854639694880476, 126.75854096959318, 포천천 2,37.89531095584674, 127.20096778249416, 진위천 2,37.09793604326866, 127.08393302456683, 남한강 2,37.460459499061464, 127.49638603216884, 청미천 1,37.12186508716677, 127.39487102679448, 시화호 1,37.30574012802834, 126.67318900588819, 한강하구 1,37.63900600625263, 126.7392737093319, 남양호 2,37.014705010495824, 126.80548911195082, 화성호 2,37.11569165016753, 126.68399070425345, 임진강 2,37.78837469359229, 126.66443256564555, 팔당호 2,37.517786765600256, 127.30085067928745, 공릉천 1,37.71153311751638, 126.84431089180522, 천수만 1,36.606686550264854, 126.42022590245743, 송정저수지 2,36.776518685002266, 127.37727865534171, 도당천 2,36.80714447844311, 126.52479040293552, 논산천 2,36.18278993438778, 127.13602531594704, 풍세천 1,36.73350817705159, 127.1244086501327, 곡교천 1,36.71877449174619, 127.15174380564193, 금강호 2,36.003067864761206, 126.7392621031086, 병천천 2,36.725838913572076, 127.33975466921613, 간월호 2,36.64982878482214, 126.45513048255029, 봉강천 1,36.764423602867765, 127.09015473839389, 삽교호 2,36.871878675924705, 126.8408688154442, 해미천 2,36.702223625170994, 126.56263020795463, 봉선저수지 2,36.122350318713586, 126.77672013431376, 아산호 2,36.90267012782007, 126.90366071698058, 잠홍지 2,36.86183091315654, 126.49751943843305, 석문간척지 2,36.98373310641944, 126.54384726738202, 대호 2,37.018417616519976, 126.48222083422783, 무한천 2,36.71991194571029, 126.82242403818584, 부남호 2,36.67319913351787, 126.35083023955421, 조류지 2,35.7835057158404, 126.63542818010029, 금강하구둑 1,36.019581075069965, 126.74774856012905, 만경강 1,35.892198153374686, 126.99399821147692, 동림저수지 1,35.549802869235755, 126.71940396468966, 동진강 1,35.68373784028254, 126.86079504883465, 원평천 3,35.74647979945319, 126.93850431156142, 전주천 2,35.802060277740146, 127.1716072485318, 산수저수지 2,36.6994319040145, 126.56852268525259, 함평대동저수지 2,35.13211104219479, 126.50607906456341, 사내간척지 2,34.46251975253601, 126.7333378843619, 만덕간척지 2,34.56578321910065, 126.7615639132014, 고막원천 2,35.06842526203833, 126.59162469994376, 주암댐 2,35.06371924138319, 127.23767782670512, 영산강 2,34.76893810284395, 126.35098968807019, 영암호 1,34.69724570173779, 126.47537026437189, 고천암 2,34.52161252340564, 126.47457655553478, 순천만 1,34.88677475630541, 127.50729078209247, 금호호 1,34.62057239836871, 126.39840653700985, 강진만 2,34.490791668173664, 126.77354817448324, 지석천 2,35.00917066621701, 126.9113644244127, 우습제 2,34.94017348080215, 126.57951161334536, 담양습지 3,35.24009556727233, 126.88387920926465, 황룡강 2,35.32701483996603, 126.79783650573678, 한탄강 2,38.20119540754313, 127.27737191150247, 토교저수지 2,38.28934502892065, 127.28936308358267, 섬강 1,37.500690845580344, 127.99213918049267, 철원평야 2,38.29310283134329, 127.21422992889252, 남대천 3,37.75220997167653, 128.90134105532326, 소양강 하류 2,37.89698617983393, 127.7454239624107, 원주천 2,37.382704055767405, 127.94147033377192, 남대천 3,38.107964222902496, 128.64361106592784, 보강천 2,36.786518139596225, 127.57854158748, 백곡지 2,36.86662724997134, 127.39976155953663, 미호천 1,36.5162887821276, 127.31976281396229, 무심천 2,36.58091002074261, 127.50346917018088, 충주호 3,36.96033958118106, 128.0662729272722, 안심습지 3,35.86502982622569, 128.74718716576282, 형산강 1,35.92345596127968, 129.23887659738637, 김천 2,36.09212308013244, 128.12331495113736, 구미 3,36.18780476544952, 128.3702147007899, 낙동강 2,35.83992615966229, 128.46110345037778, 금호강 1,35.8174026069283, 128.48104618415317, 낙동강하구 2,35.104959005687974, 128.9459320237596, 태화강 3,35.53764149997886, 129.36999476035592, 장척저수지 3,35.43456283906837, 128.49224351135572, 양산천 2,35.32377076603513, 129.020069 ...
# Index: []
#
# [0 rows x 104 columns]

# %%
aiai_local2['주소']=aiai_local['주소']

# %%
aiai_local2.head()
# Out:
#           주소 강서지구 3,37.5901984197481, 126.81362533492893  \
# 0  서울특별시 종로구                                         NaN
# 1   서울특별시 중구                                         NaN
# 2  서울특별시 용산구                                         NaN
# 3  서울특별시 성동구                                         NaN
# 4  서울특별시 광진구                                         NaN
#
#   중랑천 2,37.6030830331226, 127.072105737988  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   안양천  3,37.513562487735406, 126.87461172643478  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   탄천 2,37.49508293706438, 127.10150560559426  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   원천리천 3,37.26481224039535, 127.04976224622416  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#   서호 3,37.280408134249136, 126.98755251443214  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   안성천 1,36.99139105195746, 127.20539544460591  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   경안천 2,37.309938272435886, 127.23553552424399  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#   상패천 2,37.91927602221171, 127.05389142205611  ...  \
# 0                                         NaN  ...
# 1                                         NaN  ...
# 2                                         NaN  ...
# 3                                         NaN  ...
# 4                                         NaN  ...
#
#   목포늪 3,35.56254130753707, 128.40618339231  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   사지포 3,35.561613790429384, 128.4333952070682  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   산남저수지 3,35.35126887288887, 128.17443850327453  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   동판저수지 2,35.30133784622012, 128.68634622602417  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   화포천 2,35.31163742899077, 128.7875952437551  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   낙동강 3,35.27987524642292, 129.009763931276  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   하도리 2,33.51695001412742, 126.8838772052322  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   용수저수지 2,33.31741751732376, 126.18752882294538  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   오조리 3,33.463866194337236, 126.91796178149626  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#   종달리 3,33.49242412098807, 126.89071411147393
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
# [5 rows x 104 columns]

# %%
#aiai['위도,경도']=aiai['위도,경도'].map(lambda x:x.replace(" ",""))

# %%
#aiai_local2['위도경도']=aiai['위도,경도']

# %%
for i in tqdm(range(len(aiai_local2))):
    address=aiai_local2.loc[i,'주소']
    if address=='세종특별자치시 세종시':
        address='세종특별자치시'
    maps=naverMap.Geocode(address)
    for col in aiai_local2.columns[1:]:
        temp=col.split(',')
        aiai_local2.loc[i,col]=naverMap.direction((float(temp[1]), float(temp[2])), maps)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 229/229 [00:30<00:00,  7.47it/s]

# %%
# naverMap?

# %%
 aiai_local2.to_csv("시군구_철새도래지거리.csv", encoding='utf-8-sig', index=False)

# %% [markdown]
# ## 철새도래지-전국 시군구 가까운 순으로 정렬

# %%
 aiai_local2.head()
# Out:
#           주소 강서지구 3,37.5901984197481, 126.81362533492893  \
# 0  서울특별시 종로구                                       14.68
# 1   서울특별시 중구                                       16.48
# 2  서울특별시 용산구                                       16.86
# 3  서울특별시 성동구                                       19.89
# 4  서울특별시 광진구                                       24.37
#
#   중랑천 2,37.6030830331226, 127.072105737988  \
# 0                                     8.85
# 1                                     7.88
# 2                                    10.64
# 3                                     5.39
# 4                                     7.23
#
#   안양천  3,37.513562487735406, 126.87461172643478  \
# 0                                         11.35
# 1                                          12.2
# 2                                         10.43
# 3                                         15.34
# 4                                         18.53
#
#   탄천 2,37.49508293706438, 127.10150560559426  \
# 0                                       13.9
# 1                                      11.93
# 2                                      10.64
# 3                                        9.5
# 4                                       5.13
#
#   원천리천 3,37.26481224039535, 127.04976224622416  \
# 0                                        34.89
# 1                                        33.57
# 2                                        30.23
# 3                                        33.23
# 4                                        30.58
#
#   서호 3,37.280408134249136, 126.98755251443214  \
# 0                                        32.6
# 1                                       31.53
# 2                                       28.04
# 3                                       31.77
# 4                                       29.91
#
#   안성천 1,36.99139105195746, 127.20539544460591  \
# 0                                       67.76
# 1                                       66.26
# 2                                       63.11
# 3                                       65.34
# 4                                       61.82
#
#   경안천 2,37.309938272435886, 127.23553552424399  \
# 0                                        37.05
# 1                                        35.19
# 2                                        32.88
# 3                                         33.2
# 4                                         28.8
#
#   상패천 2,37.91927602221171, 127.05389142205611  ...  \
# 0                                       39.01  ...
# 1                                       39.83  ...
# 2                                       43.36  ...
# 3                                       39.59  ...
# 4                                        42.4  ...
#
#   목포늪 3,35.56254130753707, 128.40618339231  \
# 0                                   257.38
# 1                                   255.62
# 2                                   252.93
# 3                                   253.88
# 4                                   249.52
#
#   사지포 3,35.561613790429384, 128.4333952070682  \
# 0                                      258.68
# 1                                      256.92
# 2                                      254.24
# 3                                      255.15
# 4                                      250.77
#
#   산남저수지 3,35.35126887288887, 128.17443850327453  \
# 0                                        269.24
# 1                                        267.59
# 2                                        264.65
# 3                                        266.19
# 4                                         262.1
#
#   동판저수지 2,35.30133784622012, 128.68634622602417  \
# 0                                        295.23
# 1                                        293.44
# 2                                        290.81
# 3                                        291.62
# 4                                        287.19
#
#   화포천 2,35.31163742899077, 128.7875952437551  \
# 0                                     299.04
# 1                                     297.23
# 2                                     294.67
# 3                                     295.32
# 4                                     290.84
#
#   낙동강 3,35.27987524642292, 129.009763931276  \
# 0                                    313.13
# 1                                    311.29
# 2                                    308.85
# 3                                    309.24
# 4                                    304.66
#
#   하도리 2,33.51695001412742, 126.8838772052322  \
# 0                                     451.15
# 1                                     450.11
# 2                                     446.62
# 3                                     450.16
# 4                                     447.55
#
#   용수저수지 2,33.31741751732376, 126.18752882294538  \
# 0                                        478.65
# 1                                        477.84
# 2                                        474.31
# 3                                        478.36
# 4                                        476.32
#
#   오조리 3,33.463866194337236, 126.91796178149626  \
# 0                                       457.01
# 1                                       455.95
# 2                                       452.46
# 3                                       455.98
# 4                                       453.34
#
#   종달리 3,33.49242412098807, 126.89071411147393
# 0                                      453.87
# 1                                      452.82
# 2                                      449.33
# 3                                      452.87
# 4                                      450.25
#
# [5 rows x 104 columns]

# %%
aiai_local2=pd.read_csv('시군구_철새도래지거리.csv', encoding='utf-8-sig')
aiai_local2.head()
# Out:
#           주소  강서지구 3,37.5901984197481, 126.81362533492893  \
# 0  서울특별시 종로구                                        14.68
# 1   서울특별시 중구                                        16.48
# 2  서울특별시 용산구                                        16.86
# 3  서울특별시 성동구                                        19.89
# 4  서울특별시 광진구                                        24.37
#
#    중랑천 2,37.6030830331226, 127.072105737988  \
# 0                                      8.85
# 1                                      7.88
# 2                                     10.64
# 3                                      5.39
# 4                                      7.23
#
#    안양천  3,37.513562487735406, 126.87461172643478  \
# 0                                          11.35
# 1                                          12.20
# 2                                          10.43
# 3                                          15.34
# 4                                          18.53
#
#    탄천 2,37.49508293706438, 127.10150560559426  \
# 0                                       13.90
# 1                                       11.93
# 2                                       10.64
# 3                                        9.50
# 4                                        5.13
#
#    원천리천 3,37.26481224039535, 127.04976224622416  \
# 0                                         34.89
# 1                                         33.57
# 2                                         30.23
# 3                                         33.23
# 4                                         30.58
#
#    서호 3,37.280408134249136, 126.98755251443214  \
# 0                                        32.60
# 1                                        31.53
# 2                                        28.04
# 3                                        31.77
# 4                                        29.91
#
#    안성천 1,36.99139105195746, 127.20539544460591  \
# 0                                        67.76
# 1                                        66.26
# 2                                        63.11
# 3                                        65.34
# 4                                        61.82
#
#    경안천 2,37.309938272435886, 127.23553552424399  \
# 0                                         37.05
# 1                                         35.19
# 2                                         32.88
# 3                                         33.20
# 4                                         28.80
#
#    상패천 2,37.91927602221171, 127.05389142205611  ...  \
# 0                                        39.01  ...
# 1                                        39.83  ...
# 2                                        43.36  ...
# 3                                        39.59  ...
# 4                                        42.40  ...
#
#    목포늪 3,35.56254130753707, 128.40618339231  \
# 0                                    257.38
# 1                                    255.62
# 2                                    252.93
# 3                                    253.88
# 4                                    249.52
#
#    사지포 3,35.561613790429384, 128.4333952070682  \
# 0                                       258.68
# 1                                       256.92
# 2                                       254.24
# 3                                       255.15
# 4                                       250.77
#
#    산남저수지 3,35.35126887288887, 128.17443850327453  \
# 0                                         269.24
# 1                                         267.59
# 2                                         264.65
# 3                                         266.19
# 4                                         262.10
#
#    동판저수지 2,35.30133784622012, 128.68634622602417  \
# 0                                         295.23
# 1                                         293.44
# 2                                         290.81
# 3                                         291.62
# 4                                         287.19
#
#    화포천 2,35.31163742899077, 128.7875952437551  \
# 0                                      299.04
# 1                                      297.23
# 2                                      294.67
# 3                                      295.32
# 4                                      290.84
#
#    낙동강 3,35.27987524642292, 129.009763931276  \
# 0                                     313.13
# 1                                     311.29
# 2                                     308.85
# 3                                     309.24
# 4                                     304.66
#
#    하도리 2,33.51695001412742, 126.8838772052322  \
# 0                                      451.15
# 1                                      450.11
# 2                                      446.62
# 3                                      450.16
# 4                                      447.55
#
#    용수저수지 2,33.31741751732376, 126.18752882294538  \
# 0                                         478.65
# 1                                         477.84
# 2                                         474.31
# 3                                         478.36
# 4                                         476.32
#
#    오조리 3,33.463866194337236, 126.91796178149626  \
# 0                                        457.01
# 1                                        455.95
# 2                                        452.46
# 3                                        455.98
# 4                                        453.34
#
#    종달리 3,33.49242412098807, 126.89071411147393
# 0                                       453.87
# 1                                       452.82
# 2                                       449.33
# 3                                       452.87
# 4                                       450.25
#
# [5 rows x 104 columns]

# %%
aiai_local2.isnull().sum()
# Out:
# 주소                                               0
# 강서지구 3,37.5901984197481, 126.81362533492893      0
# 중랑천 2,37.6030830331226, 127.072105737988         0
# 안양천  3,37.513562487735406, 126.87461172643478    0
# 탄천 2,37.49508293706438, 127.10150560559426       0
#                                                 ..
# 낙동강 3,35.27987524642292, 129.009763931276        0
# 하도리 2,33.51695001412742, 126.8838772052322       0
# 용수저수지 2,33.31741751732376, 126.18752882294538    0
# 오조리 3,33.463866194337236, 126.91796178149626     0
# 종달리 3,33.49242412098807, 126.89071411147393      0
# Length: 104, dtype: int64

# %%
for col in aiai_local2.columns[1:]:
    temp=col.split(',')
    aiai_local2=aiai_local2.rename(columns={col:temp[0]})

# %%
aiai_local2.columns
# Out:
# Index(['주소', '강서지구 3', '중랑천 2', '안양천  3', '탄천 2', '원천리천 3', '서호 3', '안성천 1',
#        '경안천 2', '상패천 2',
#        ...
#        '목포늪 3', '사지포 3', '산남저수지 3', '동판저수지 2', '화포천 2', '낙동강 3', '하도리 2',
#        '용수저수지 2', '오조리 3', '종달리 3'],
#       dtype='object', length=104)

# %%
#km앞에, 주소가 뒤에 나오게

#각 지점별 거리가 저장된 df
aiai_local2

#결과를 저장할 df 생성
near_order = DataFrame(index = aiai_local2.index,columns = range(len(aiai_local2.columns[1:])))

#column 하나를 기준으로 정렬, 반올림, 문자열로 변환, 
for i in range(len(near_order)):
    temp = pd.DataFrame(aiai_local2.iloc[i])
    temp = temp.iloc[1:].sort_values(by=temp.columns[0])
    temp = temp.astype('str')
    temp = temp.reset_index()
    temp = temp.iloc[:,1]+ ' '+ temp['index']
    near_order.iloc[i,:] = temp
#display(near_order)
#del near_order[0]

near_order.head()
# Out:
#             0             1             2             3             4    \
# 0    8.85 중랑천 2  11.35 안양천  3     13.9 탄천 2  14.68 강서지구 3   19.39 공릉천 1
# 1    7.88 중랑천 2    11.93 탄천 2   12.2 안양천  3  16.48 강서지구 3   21.26 공릉천 1
# 2  10.43 안양천  3   10.64 중랑천 2    10.64 탄천 2  16.86 강서지구 3   23.71 공릉천 1
# 3    5.39 중랑천 2      9.5 탄천 2  15.34 안양천  3  19.89 강서지구 3   23.63 공릉천 1
# 4     5.13 탄천 2    7.23 중랑천 2  18.53 안양천  3    19.4 팔당호 2  24.37 강서지구 3
#
#             5             6             7           8             9    ...  \
# 0  22.32 한강하구 1   29.06 팔당호 2  29.71 왕송호수 3   32.6 서호 3  34.89 원천리천 3  ...
# 1  24.24 한강하구 1   27.22 팔당호 2  28.85 왕송호수 3  31.53 서호 3  33.57 원천리천 3  ...
# 2   25.1 한강하구 1  25.31 왕송호수 3   27.42 팔당호 2  28.04 서호 3  30.23 원천리천 3  ...
# 3   23.83 팔당호 2  27.53 한강하구 1  29.54 왕송호수 3  31.77 서호 3    33.2 경안천 2  ...
# 4  28.33 왕송호수 3   28.45 공릉천 1    28.8 경안천 2  29.91 서호 3  30.58 원천리천 3  ...
#
#               93            94              95            96            97   \
# 0  326.15 낙동강하구 2  332.47 금호호 1  335.01 만덕간척지 2  342.37 고천암 2  343.28 강진만 2
# 1  324.35 낙동강하구 2  331.67 금호호 1  334.04 만덕간척지 2  341.53 고천암 2   342.3 강진만 2
# 2  321.78 낙동강하구 2  328.14 금호호 1  330.53 만덕간척지 2   338.0 고천암 2  338.79 강진만 2
# 3    322.67 영암호 1  332.22 금호호 1  334.24 만덕간척지 2  341.99 고천암 2  342.48 강진만 2
# 4    320.61 영암호 1  330.24 금호호 1  331.82 만덕간척지 2   339.9 고천암 2  340.04 강진만 2
#
#               98            99            100           101             102
# 0  346.63 사내간척지 2  451.15 하도리 2  453.87 종달리 3  457.01 오조리 3  478.65 용수저수지 2
# 1  345.67 사내간척지 2  450.11 하도리 2  452.82 종달리 3  455.95 오조리 3  477.84 용수저수지 2
# 2  342.15 사내간척지 2  446.62 하도리 2  449.33 종달리 3  452.46 오조리 3  474.31 용수저수지 2
# 3  345.89 사내간척지 2  450.16 하도리 2  452.87 종달리 3  455.98 오조리 3  478.36 용수저수지 2
# 4  343.48 사내간척지 2  447.55 하도리 2  450.25 종달리 3  453.34 오조리 3  476.32 용수저수지 2
#
# [5 rows x 103 columns]

# %%
near_order.to_csv("전국시군구_철새도래지_위험점수(가까운순).csv", encoding='utf-8-sig',index=False)

# %%
aiai_birds_near=pd.read_csv("전국시군구_철새도래지_위험점수(가까운순).csv", encoding='utf-8-sig')

# %%
aiai_birds_near.head()
# Out:
#               0             1             2             3             4  \
# 0    8.85 중랑천 2  11.35 안양천  3     13.9 탄천 2  14.68 강서지구 3   19.39 공릉천 1
# 1    7.88 중랑천 2    11.93 탄천 2   12.2 안양천  3  16.48 강서지구 3   21.26 공릉천 1
# 2  10.43 안양천  3   10.64 중랑천 2    10.64 탄천 2  16.86 강서지구 3   23.71 공릉천 1
# 3    5.39 중랑천 2      9.5 탄천 2  15.34 안양천  3  19.89 강서지구 3   23.63 공릉천 1
# 4     5.13 탄천 2    7.23 중랑천 2  18.53 안양천  3    19.4 팔당호 2  24.37 강서지구 3
#
#               5             6             7           8             9  ...  \
# 0  22.32 한강하구 1   29.06 팔당호 2  29.71 왕송호수 3   32.6 서호 3  34.89 원천리천 3  ...
# 1  24.24 한강하구 1   27.22 팔당호 2  28.85 왕송호수 3  31.53 서호 3  33.57 원천리천 3  ...
# 2   25.1 한강하구 1  25.31 왕송호수 3   27.42 팔당호 2  28.04 서호 3  30.23 원천리천 3  ...
# 3   23.83 팔당호 2  27.53 한강하구 1  29.54 왕송호수 3  31.77 서호 3    33.2 경안천 2  ...
# 4  28.33 왕송호수 3   28.45 공릉천 1    28.8 경안천 2  29.91 서호 3  30.58 원천리천 3  ...
#
#                93            94              95            96            97  \
# 0  326.15 낙동강하구 2  332.47 금호호 1  335.01 만덕간척지 2  342.37 고천암 2  343.28 강진만 2
# 1  324.35 낙동강하구 2  331.67 금호호 1  334.04 만덕간척지 2  341.53 고천암 2   342.3 강진만 2
# 2  321.78 낙동강하구 2  328.14 금호호 1  330.53 만덕간척지 2   338.0 고천암 2  338.79 강진만 2
# 3    322.67 영암호 1  332.22 금호호 1  334.24 만덕간척지 2  341.99 고천암 2  342.48 강진만 2
# 4    320.61 영암호 1  330.24 금호호 1  331.82 만덕간척지 2   339.9 고천암 2  340.04 강진만 2
#
#                98            99           100           101             102
# 0  346.63 사내간척지 2  451.15 하도리 2  453.87 종달리 3  457.01 오조리 3  478.65 용수저수지 2
# 1  345.67 사내간척지 2  450.11 하도리 2  452.82 종달리 3  455.95 오조리 3  477.84 용수저수지 2
# 2  342.15 사내간척지 2  446.62 하도리 2  449.33 종달리 3  452.46 오조리 3  474.31 용수저수지 2
# 3  345.89 사내간척지 2  450.16 하도리 2  452.87 종달리 3  455.98 오조리 3  478.36 용수저수지 2
# 4  343.48 사내간척지 2  447.55 하도리 2  450.25 종달리 3  453.34 오조리 3  476.32 용수저수지 2
#
# [5 rows x 103 columns]

# %%
# 행 값 전국 시군구 불러오기
ai_local=aiai_local2['주소']
ai_local.head()
# Out:
# 0    서울특별시 종로구
# 1     서울특별시 중구
# 2    서울특별시 용산구
# 3    서울특별시 성동구
# 4    서울특별시 광진구
# Name: 주소, dtype: object

# %%
aiai_birds_near=pd.concat([ai_local,aiai_birds_near], axis=1)
aiai_birds_near.head()
# Out:
#           주소             0             1             2             3  \
# 0  서울특별시 종로구    8.85 중랑천 2  11.35 안양천  3     13.9 탄천 2  14.68 강서지구 3
# 1   서울특별시 중구    7.88 중랑천 2    11.93 탄천 2   12.2 안양천  3  16.48 강서지구 3
# 2  서울특별시 용산구  10.43 안양천  3   10.64 중랑천 2    10.64 탄천 2  16.86 강서지구 3
# 3  서울특별시 성동구    5.39 중랑천 2      9.5 탄천 2  15.34 안양천  3  19.89 강서지구 3
# 4  서울특별시 광진구     5.13 탄천 2    7.23 중랑천 2  18.53 안양천  3    19.4 팔당호 2
#
#               4             5             6             7           8  ...  \
# 0   19.39 공릉천 1  22.32 한강하구 1   29.06 팔당호 2  29.71 왕송호수 3   32.6 서호 3  ...
# 1   21.26 공릉천 1  24.24 한강하구 1   27.22 팔당호 2  28.85 왕송호수 3  31.53 서호 3  ...
# 2   23.71 공릉천 1   25.1 한강하구 1  25.31 왕송호수 3   27.42 팔당호 2  28.04 서호 3  ...
# 3   23.63 공릉천 1   23.83 팔당호 2  27.53 한강하구 1  29.54 왕송호수 3  31.77 서호 3  ...
# 4  24.37 강서지구 3  28.33 왕송호수 3   28.45 공릉천 1    28.8 경안천 2  29.91 서호 3  ...
#
#                93            94              95            96            97  \
# 0  326.15 낙동강하구 2  332.47 금호호 1  335.01 만덕간척지 2  342.37 고천암 2  343.28 강진만 2
# 1  324.35 낙동강하구 2  331.67 금호호 1  334.04 만덕간척지 2  341.53 고천암 2   342.3 강진만 2
# 2  321.78 낙동강하구 2  328.14 금호호 1  330.53 만덕간척지 2   338.0 고천암 2  338.79 강진만 2
# 3    322.67 영암호 1  332.22 금호호 1  334.24 만덕간척지 2  341.99 고천암 2  342.48 강진만 2
# 4    320.61 영암호 1  330.24 금호호 1  331.82 만덕간척지 2   339.9 고천암 2  340.04 강진만 2
#
#                98            99           100           101             102
# 0  346.63 사내간척지 2  451.15 하도리 2  453.87 종달리 3  457.01 오조리 3  478.65 용수저수지 2
# 1  345.67 사내간척지 2  450.11 하도리 2  452.82 종달리 3  455.95 오조리 3  477.84 용수저수지 2
# 2  342.15 사내간척지 2  446.62 하도리 2  449.33 종달리 3  452.46 오조리 3  474.31 용수저수지 2
# 3  345.89 사내간척지 2  450.16 하도리 2  452.87 종달리 3  455.98 오조리 3  478.36 용수저수지 2
# 4  343.48 사내간척지 2  447.55 하도리 2  450.25 종달리 3  453.34 오조리 3  476.32 용수저수지 2
#
# [5 rows x 104 columns]

# %%
aiai_birds_near.to_csv("전국시군구_철새도래지_위험점수(가까운순).csv", encoding='utf-8-sig',index=False)

# %%
aiai_dorage=pd.DataFrame(columns=['시도','시군구','거리','위험분류','risk'])
for i in tqdm(range(len(aiai_birds_near))):
    address=aiai_birds_near.loc[i,'주소'].split()
    for col in aiai_birds_near.columns[1:]:
        name=aiai_birds_near.loc[i,col].split()
        aiai_dorage=aiai_dorage.append({'시도':address[0],'시군구':address[1],'거리':name[0],'위험분류':name[-1]}, ignore_index=True)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 229/229 [01:52<00:00,  2.04it/s]

# %%
aiai_dorage.head()
# Out:
#       시도  시군구     거리 위험분류 risk
# 0  서울특별시  종로구   8.85    2  NaN
# 1  서울특별시  종로구  11.35    3  NaN
# 2  서울특별시  종로구   13.9    2  NaN
# 3  서울특별시  종로구  14.68    3  NaN
# 4  서울특별시  종로구  19.39    1  NaN

# %%
aiai_dorage.to_csv("전국시군구_철새도래지_위험분류테이블(초안).csv", encoding='utf-8-sig',index=False)

# %% [markdown]
# ## 클러스터링(위험도 테이블 만들기)

# %%
import pandas as np
import datetime
import pandas as pd
import numpy as np
import seaborn as sns
import scipy as sp
from scipy import stats
from matplotlib import pyplot as plt

# %%
aiai_dorage=pd.read_csv("전국시군구_철새도래지_위험분류테이블(초안).csv", encoding='utf-8-sig')

# %%
x=aiai_dorage['거리']
y=aiai_dorage['위험분류']
xy=pd.concat([x,y], axis=1)
xy
# Out:
#            거리  위험분류
# 0        8.85     2
# 1       11.35     3
# 2       13.90     2
# 3       14.68     3
# 4       19.39     1
# ...       ...   ...
# 23582  543.19     3
# 23583  553.91     2
# 23584  563.43     2
# 23585  563.76     2
# 23586  571.57     3
#
# [23587 rows x 2 columns]

# %%
#정규화 minmax 하기
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaler.fit(xy)
Normalized_Values = scaler.transform(xy)

# %%
Normalized_Values
# Out:
# array([[0.01391467, 0.5       ],
#        [0.01788123, 1.        ],
#        [0.02192711, 0.5       ],
#        ...,
#        [0.89382328, 0.5       ],
#        [0.89434687, 0.5       ],
#        [0.90673838, 1.        ]])

# %%
from sklearn.cluster import KMeans
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=11, random_state =0, init='k-means++').fit(Normalized_Values)

# %%
kmeans.labels_
# Out:
# array([0, 5, 0, ..., 8, 8, 7])

# %%
kmeans.cluster_centers_
# Out:
# array([[ 1.16149362e-01,  5.00000000e-01],
#        [ 4.42744405e-01,  1.00000000e+00],
#        [ 4.68335048e-01,  6.66133815e-16],
#        [ 4.24847304e-01,  5.00000000e-01],
#        [ 1.25153641e-01, -2.22044605e-16],
#        [ 1.01844076e-01,  1.00000000e+00],
#        [ 2.78473765e-01,  5.00000000e-01],
#        [ 6.89387807e-01,  1.00000000e+00],
#        [ 5.95993165e-01,  5.00000000e-01],
#        [ 2.99692449e-01,  4.44089210e-16],
#        [ 2.73792431e-01,  1.00000000e+00]])

# %%
kmeans.inertia_
# Out:
# 63.84807671217516

# %%
xy
# Out:
#            거리  위험분류
# 0        8.85     2
# 1       11.35     3
# 2       13.90     2
# 3       14.68     3
# 4       19.39     1
# ...       ...   ...
# 23582  543.19     3
# 23583  553.91     2
# 23584  563.43     2
# 23585  563.76     2
# 23586  571.57     3
#
# [23587 rows x 2 columns]

# %%
sb.lmplot('위험분류', '거리', data=xy, fit_reg=False, scatter_kws={"s": 100})
plt.title('k-means Example')
plt.xlabel('위험분류 ')
plt.ylabel('거리')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 50948 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 54744 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 48516 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 47448 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44144 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 47532 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 50948 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 54744 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 48516 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 47448 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 44144 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 47532 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
aiai_dorage.head()
# Out:
#       시도  시군구     거리  위험분류  risk  cluster
# 0  서울특별시  종로구   8.85     2   NaN        0
# 1  서울특별시  종로구  11.35     3   NaN        5
# 2  서울특별시  종로구  13.90     2   NaN        0
# 3  서울특별시  종로구  14.68     3   NaN        5
# 4  서울특별시  종로구  19.39     1   NaN        4

# %%
sb.lmplot('거리', '위험분류', data=aiai_dorage, fit_reg=False, scatter_kws={"s":150}, hue='cluster')
plt.title('k-means Example')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44144 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 47532 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 44144 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 47532 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 50948 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 54744 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 48516 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 47448 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 50948 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 54744 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 48516 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 47448 missing from current font.
#   font.set_text(s, 0, flags=flags)
# Text(0.5, 1.0, 'k-means Example')

# %%
#aiai_dorage.to_csv("철새도래지_위험도테이블(초안).csv", encoding='utf-8-sig', index=False)
