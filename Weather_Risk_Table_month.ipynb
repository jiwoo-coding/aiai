# %%
import pandas as pd
import numpy as np
import datetime   # datetime 내 timedelta는 몇주전후 까지만 나와 있음
from dateutil.relativedelta import relativedelta # 몇달전후, 몇년전후를 구하기 위함
from tqdm import tqdm
from scipy import stats

# %%
data=pd.read_csv('HPAI_Weather_occur.csv', encoding='utf-8-sig')

# %%
data.head()
# Out:
#                 주소     축종     사육수       진단일       발생일  지역코드 지역명   시도  시군구  \
# 0  강원도 원주시 귀래면 주포리  닭-산란계  170000  20210224  20210223   114  원주  강원도  원주시
# 1   강원도 인제군 기린면 북리  닭-산란계   28500  20170107  20170103   211  인제  강원도  인제군
# 2  강원도 철원군 갈말읍 강포리  닭-산란계   16000  20161212  20161209    95  철원  강원도  철원군
# 3  강원도 철원군 갈말읍 강포리  닭-산란계   30000  20161203  20161130    95  철원  강원도  철원군
# 4  강원도 춘천시 사북면 지촌리  닭-산란계      48  20080507  20080507   101  춘천  강원도  춘천시
#
#   location      date  avg_temp(C)  lowest_temp(C)  highest_temp(C)  \
# 0       원주  20210223          1.9            -1.2              6.4
# 1       인제  20170103          1.2            -4.0              6.2
# 2       철원  20161209         -0.1            -6.3              3.7
# 3       철원  20161130          3.2            -4.7              8.9
# 4       춘천  20080507         13.2             7.3             20.9
#
#    daily_rain(mm)  maxWsWd(16방위)  avg_wind(m/s)  avg_r_humidity(%)
# 0             0.0          270.0            1.4               28.0
# 1             0.0          160.0            2.2               60.1
# 2             1.7          270.0            1.6               68.9
# 3             1.2          230.0            0.9               72.1
# 4            17.0          180.0            0.6               66.1

# %%
# 필요없는 열 삭제
# 평균온도, 일강수량, 평균풍속, 평균상대습도 data만 확보
data_df=data.drop(['축종', '주소', '진단일', '사육수', '지역명', 'location', 'date', 'lowest_temp(C)',
                  'highest_temp(C)', 'maxWsWd(16방위)'], axis=1)

# %%
data_df['발생일']=data_df['발생일'].astype('str')

# %%
data_df.head()
# Out:
#         발생일  지역코드   시도  시군구  avg_temp(C)  daily_rain(mm)  avg_wind(m/s)  \
# 0  20210223   114  강원도  원주시          1.9             0.0            1.4
# 1  20170103   211  강원도  인제군          1.2             0.0            2.2
# 2  20161209    95  강원도  철원군         -0.1             1.7            1.6
# 3  20161130    95  강원도  철원군          3.2             1.2            0.9
# 4  20080507   101  강원도  춘천시         13.2            17.0            0.6
#
#    avg_r_humidity(%)
# 0               28.0
# 1               60.1
# 2               68.9
# 3               72.1
# 4               66.1

# %%
# 문자열을 datetime 형식으로 바꾸기
data_df['발생일']=data_df['발생일'].map(lambda x : datetime.datetime.strptime(x, '%Y%m%d'))

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1122 entries, 0 to 1121
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   발생일                1122 non-null   datetime64[ns]
#  1   지역코드               1122 non-null   int64
#  2   시도                 1122 non-null   object
#  3   시군구                1122 non-null   object
#  4   avg_temp(C)        1122 non-null   float64
#  5   daily_rain(mm)     1122 non-null   float64
#  6   avg_wind(m/s)      1122 non-null   float64
#  7   avg_r_humidity(%)  1122 non-null   float64
# dtypes: datetime64[ns](1), float64(4), int64(1), object(2)
# memory usage: 70.2+ KB

# %%
# 월별 데이터 만들기
data_df['month']=data_df['발생일'].map(lambda x: x.month)
data_df['year']=data_df['발생일'].map(lambda x: x.year)

# %%
data_df.head()
# Out:
#          발생일  지역코드   시도  시군구  avg_temp(C)  daily_rain(mm)  avg_wind(m/s)  \
# 0 2021-02-23   114  강원도  원주시          1.9             0.0            1.4
# 1 2017-01-03   211  강원도  인제군          1.2             0.0            2.2
# 2 2016-12-09    95  강원도  철원군         -0.1             1.7            1.6
# 3 2016-11-30    95  강원도  철원군          3.2             1.2            0.9
# 4 2008-05-07   101  강원도  춘천시         13.2            17.0            0.6
#
#    avg_r_humidity(%)  month  year
# 0               28.0      2  2021
# 1               60.1      1  2017
# 2               68.9     12  2016
# 3               72.1     11  2016
# 4               66.1      5  2008

# %% [markdown]
# #### 월별로 된 시도 데이터 중 발생했던 년도와 발생하지 않았던 년도를 비교하기
#     1. 기간은 2003~2020년까지
#     2. 비교를 위해서는 발생건수로 확인한다. (가중치가 cnt 비율로 시군별로 들어갈 수 있을 듯)

# %%
import weatherAPI

# %%
data_df['cnt']=1

# %%
# 발생한 날 시군구 월별 기후 평균 구하기
sido_df=data_df.groupby(['year','month','시도','시군구']).mean()
sido_df['cnt']=data_df.groupby(['year','month','시도','시군구']).sum()['cnt']

# %%
sido_df.reset_index(inplace=True)

# %%
sido_df.head()
# Out:
#    year  month     시도  시군구  지역코드  avg_temp(C)  daily_rain(mm)  avg_wind(m/s)  \
# 0  2003     12    경기도  이천시   203         0.00             0.0       1.600000
# 1  2003     12   경상북도  경주시   138         6.65             0.0       2.625000
# 2  2003     12  울산광역시  울주군   152         0.30             0.0       3.200000
# 3  2003     12   전라남도  나주시   156         0.75             0.0       1.400000
# 4  2003     12   충청남도  천안시   232         0.00             0.0       1.633333
#
#    avg_r_humidity(%)  cnt
# 0             66.100    2
# 1             44.775    4
# 2             29.400    2
# 3             70.200    2
# 4             76.000    3

# %%
cols_name=['avg_temp(C)','daily_rain(mm)','avg_wind(m/s)','avg_r_humidity(%)']
other_sido_df=pd.DataFrame(columns=['year','month','시도','시군구','지역코드']+cols_name)

# %%
for year in range(2003,2021):
    if year not in set(sido_df['year']):
        for n, group in sido_df.groupby(['month','시도','시군구','지역코드']):
            group.reset_index(inplace=True, drop=True)
            if len(str(n[0]))==1:
                temp_month='0'+str(n[0])
            else:
                temp_month=str(n[0])
            start_date=str(year)+temp_month+'01'
            temp_date=datetime.datetime.strptime(start_date, '%Y%m%d')
            end_date=temp_date+relativedelta(months=1)-datetime.timedelta(days=1)
            end_date=end_date.strftime('%Y%m%d')
            try:
                temp_df=weatherAPI.load2(start_date, end_date, group.loc[0,'지역코드'])
                temp_df.drop(['location', 'date', 'lowest_temp(C)', 'highest_temp(C)', 'maxWsWd(16방위)'], axis=1, inplace=True)
                other_sido_df=other_sido_df.append(np.round(temp_df.mean(),1), ignore_index=True)
                other_sido_df.iloc[-1,0]=year
                other_sido_df.iloc[-1,1]=n[0]
                other_sido_df.iloc[-1,2]=str(n[1])
                other_sido_df.iloc[-1,3]=str(n[2])
                other_sido_df.iloc[-1,4]=n[3]
            except:
                print(f'error, start_date={start_date}, end_date={end_date}, code={group.loc[0,"지역코드"]}')
# Out:
# API error
# error, start_date=20050101, end_date=20050131, code=239
# API error
# error, start_date=20050101, end_date=20050131, code=259
# API error
# error, start_date=20050101, end_date=20050131, code=174
# API error
# error, start_date=20050101, end_date=20050131, code=160
# API error
# error, start_date=20050101, end_date=20050131, code=258
# API error
# error, start_date=20050101, end_date=20050131, code=252
# API error
# error, start_date=20050101, end_date=20050131, code=258
# API error
# error, start_date=20050101, end_date=20050131, code=251
# API error
# error, start_date=20050101, end_date=20050131, code=177
# API error
# error, start_date=20050201, end_date=20050228, code=257
# API error
# error, start_date=20050201, end_date=20050228, code=259
# API error
# error, start_date=20050201, end_date=20050228, code=174
# API error
# error, start_date=20050201, end_date=20050228, code=174
# API error
# error, start_date=20050201, end_date=20050228, code=252
# API error
# error, start_date=20050201, end_date=20050228, code=252
# API error
# error, start_date=20050201, end_date=20050228, code=251
# API error
# error, start_date=20050201, end_date=20050228, code=177
# API error
# error, start_date=20050301, end_date=20050331, code=283
# API error
# error, start_date=20050301, end_date=20050331, code=259
# API error
# error, start_date=20050301, end_date=20050331, code=174
# API error
# error, start_date=20050301, end_date=20050331, code=174
# API error
# error, start_date=20050301, end_date=20050331, code=252
# API error
# error, start_date=20050301, end_date=20050331, code=252
# API error
# error, start_date=20050301, end_date=20050331, code=251
# API error
# error, start_date=20050301, end_date=20050331, code=254
# API error
# error, start_date=20050401, end_date=20050430, code=259
# API error
# error, start_date=20050401, end_date=20050430, code=251
# API error
# error, start_date=20050501, end_date=20050531, code=259
# API error
# error, start_date=20050601, end_date=20050630, code=257
# API error
# error, start_date=20050601, end_date=20050630, code=254
# API error
# error, start_date=20050701, end_date=20050731, code=174
# API error
# error, start_date=20050701, end_date=20050731, code=252
# API error
# error, start_date=20050901, end_date=20050930, code=259
# API error
# error, start_date=20050901, end_date=20050930, code=174
# API error
# error, start_date=20051001, end_date=20051031, code=258
# API error
# error, start_date=20051101, end_date=20051130, code=283
# API error
# error, start_date=20051101, end_date=20051130, code=174
# API error
# error, start_date=20051101, end_date=20051130, code=258
# API error
# error, start_date=20051101, end_date=20051130, code=251
# API error
# error, start_date=20051201, end_date=20051231, code=257
# API error
# error, start_date=20051201, end_date=20051231, code=283
# API error
# error, start_date=20051201, end_date=20051231, code=174
# API error
# error, start_date=20051201, end_date=20051231, code=174
# API error
# error, start_date=20051201, end_date=20051231, code=268
# API error
# error, start_date=20051201, end_date=20051231, code=251
# API error
# error, start_date=20051201, end_date=20051231, code=254
# API error
# error, start_date=20090101, end_date=20090131, code=239
# API error
# error, start_date=20090101, end_date=20090131, code=259
# API error
# error, start_date=20090101, end_date=20090131, code=174
# API error
# error, start_date=20090101, end_date=20090131, code=160
# API error
# error, start_date=20090101, end_date=20090131, code=258
# API error
# error, start_date=20090101, end_date=20090131, code=258
# API error
# error, start_date=20090101, end_date=20090131, code=177
# API error
# error, start_date=20090201, end_date=20090228, code=259
# API error
# error, start_date=20090201, end_date=20090228, code=174
# API error
# error, start_date=20090201, end_date=20090228, code=174
# API error
# error, start_date=20090201, end_date=20090228, code=177
# API error
# error, start_date=20090301, end_date=20090331, code=283
# API error
# error, start_date=20090301, end_date=20090331, code=259
# API error
# error, start_date=20090301, end_date=20090331, code=174
# API error
# error, start_date=20090301, end_date=20090331, code=174
# API error
# error, start_date=20090401, end_date=20090430, code=259
# API error
# error, start_date=20090501, end_date=20090531, code=259
# API error
# error, start_date=20090701, end_date=20090731, code=174
# API error
# error, start_date=20090901, end_date=20090930, code=259
# API error
# error, start_date=20090901, end_date=20090930, code=174
# API error
# error, start_date=20091001, end_date=20091031, code=258
# API error
# error, start_date=20091101, end_date=20091130, code=283
# API error
# error, start_date=20091101, end_date=20091130, code=174
# API error
# error, start_date=20091101, end_date=20091130, code=258
# API error
# error, start_date=20091201, end_date=20091231, code=283
# API error
# error, start_date=20091201, end_date=20091231, code=174
# API error
# error, start_date=20091201, end_date=20091231, code=174
# API error
# error, start_date=20091201, end_date=20091231, code=268
# API error
# error, start_date=20120101, end_date=20120131, code=239
# API error
# error, start_date=20120101, end_date=20120131, code=160
# API error
# error, start_date=20120101, end_date=20120131, code=177
# API error
# error, start_date=20120201, end_date=20120229, code=177
# API error
# error, start_date=20121201, end_date=20121231, code=268
# API error
# error, start_date=20130101, end_date=20130131, code=239
# API error
# error, start_date=20130101, end_date=20130131, code=160
# API error
# error, start_date=20130101, end_date=20130131, code=177
# API error
# error, start_date=20130201, end_date=20130228, code=177
# API error
# error, start_date=20131201, end_date=20131231, code=268
# API error
# error, start_date=20190101, end_date=20190131, code=239
# API error
# error, start_date=20190101, end_date=20190131, code=160

# %%
# 안뽑히는게 있음
weatherAPI.load2('20190101', '20190131', '160')
# Out:
# API error

# %%
other_sido_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1374 entries, 0 to 1373
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   year               1374 non-null   float64
#  1   month              1374 non-null   float64
#  2   시도                 1374 non-null   object
#  3   시군구                1374 non-null   object
#  4   지역코드               1374 non-null   float64
#  5   avg_temp(C)        1374 non-null   float64
#  6   daily_rain(mm)     1374 non-null   float64
#  7   avg_wind(m/s)      1374 non-null   float64
#  8   avg_r_humidity(%)  1374 non-null   float64
# dtypes: float64(7), object(2)
# memory usage: 96.7+ KB

# %%
other_sido_df.head()
# Out:
#      year  month   시도   시군구   지역코드  avg_temp(C)  daily_rain(mm)  \
# 0  2005.0    1.0  강원도   인제군  211.0         -5.4             0.3
# 1  2005.0    1.0  강원도   횡성군  114.0         -3.3             0.1
# 2  2005.0    1.0  경기도   광주시  203.0         -3.1             0.1
# 3  2005.0    1.0  경기도   김포시  112.0         -1.1             0.1
# 4  2005.0    1.0  경기도  남양주시  108.0         -2.5             0.1
#
#    avg_wind(m/s)  avg_r_humidity(%)
# 0            1.8               60.9
# 1            1.3               55.8
# 2            1.2               62.1
# 3            3.1               54.1
# 4            2.4               52.2

# %%
# 시도 평균을 내서 월별 발생월 비교하기
other=np.round(other_sido_df.groupby(['month','시도']).mean(),1)

# %%
# 의미없는 열 제거
other.drop(['year','지역코드'], axis=1, inplace=True)

# %%
other.reset_index(inplace=True)

# %%
other['month']=other['month'].astype('int')

# %%
other
# Out:
#     month     시도  avg_temp(C)  daily_rain(mm)  avg_wind(m/s)  \
# 0       1    강원도         -4.4             0.2            1.4
# 1       1    경기도         -3.3             0.3            1.6
# 2       1   경상남도          0.1             0.4            1.6
# 3       1   경상북도         -0.3             0.6            2.3
# 4       1  부산광역시          3.1             0.5            3.3
# ..    ...    ...          ...             ...            ...
# 73     12  인천광역시         -1.0             0.8            3.4
# 74     12   전라남도          2.2             1.4            2.1
# 75     12   전라북도          0.5             1.5            1.6
# 76     12   충청남도         -1.5             1.1            1.6
# 77     12   충청북도         -1.7             1.0            1.3
#
#     avg_r_humidity(%)
# 0                60.0
# 1                58.9
# 2                54.5
# 3                50.7
# 4                41.8
# ..                ...
# 73               64.5
# 74               68.8
# 75               71.8
# 76               72.6
# 77               67.8
#
# [78 rows x 6 columns]

# %%
# 발생월
occur=np.round(sido_df.groupby(['month','시도']).mean(),1)
occur['cnt']=sido_df.groupby(['month','시도'])['cnt'].sum()

# %%
# 의미없는 열 제거
occur.drop(['year','지역코드'], axis=1, inplace=True)

# %%
occur.reset_index(inplace=True)
