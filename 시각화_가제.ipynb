# %%
pip install pydeck
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install plotly

# %%
import geopandas as gpd
import pandas as pd
import matplotlib as mpl
import folium
import webbrowser
from folium import plugins
import matplotlib.pyplot as plt
from shapely.geometry import Point, Polygon, LineString
import matplotlib.font_manager as fm
import json
import pydeck as pdk
import plotly.express as px
import os 
#import mapboxgl


font_name = fm.FontProperties(fname='C:/Windows/Fonts/H2GSRB.TTF').get_name()
mpl.rc('font', family=font_name)

# %%
korea0= gpd.GeoDataFrame.from_file('시각화_data/SIG2.json', encoding='cp949')
#korea1= gpd.GeoDataFrame.from_file('SIG_202101/TL_SCCO_SIG20.shp', encoding='cp949')
#korea2= gpd.GeoDataFrame.from_file('Z_SOP_BND_SIGUNGU_PG/Z_SOP_BND_SIGUNGU_PG.shp', encoding='cp949')
#local= pd.read_csv('전국시군구위험도가제.csv'encoding='cp949',dtype=str)

# %%
korea0=korea0.set_index('SIG_KOR_NM')
korea0
# Out:
#            SIG_CD       SIG_ENG_NM  \
# SIG_KOR_NM
# 춘천시         42110     Chuncheon-si
# 원주시         42130         Wonju-si
# 강릉시         42150     Gangneung-si
# 동해시         42170       Donghae-si
# 태백시         42190       Taebaek-si
# ...           ...              ...
# 증평군         43745  Jeungpyeong-gun
# 진천군         43750     Jincheon-gun
# 괴산군         43760       Goesan-gun
# 음성군         43770     Eumseong-gun
# 단양군         43800      Danyang-gun
#
#                                                      geometry
# SIG_KOR_NM
# 춘천시         POLYGON ((127.58509 38.08062, 127.58474 38.080...
# 원주시         POLYGON ((127.93580 37.50246, 127.93525 37.502...
# 강릉시         MULTIPOLYGON (((129.04785 37.64961, 129.04781 ...
# 동해시         MULTIPOLYGON (((129.15821 37.47636, 129.15821 ...
# 태백시         POLYGON ((128.91030 37.06831, 128.91036 37.069...
# ...                                                       ...
# 증평군         POLYGON ((127.63781 36.84565, 127.63733 36.845...
# ...

# %%
locals=pd.read_csv("전국시군구위험도가제.csv", encoding='utf-8-sig')
locals

# %%
fig = px.choropleth(c geojson=geometry_gj, locations='SIG_KOR_NM', color='자가용_int',
                                color_continuous_scale='Blues',
                                featureidkey='properties.EMD_KOR_NM')
fig.update_geos(fitbounds="loar_df,cations", visible=False)
fig.update_layout(title_text='용인시 법정동 별 자가용 등록 대수', title_font_size=20)
# Out:
#            SIG_CD       SIG_ENG_NM  \
# SIG_KOR_NM
# 춘천시         42110     Chuncheon-si
# 원주시         42130         Wonju-si
# 강릉시         42150     Gangneung-si
# 동해시         42170       Donghae-si
# 태백시         42190       Taebaek-si
# ...           ...              ...
# 증평군         43745  Jeungpyeong-gun
# 진천군         43750     Jincheon-gun
# 괴산군         43760       Goesan-gun
# 음성군         43770     Eumseong-gun
# 단양군         43800      Danyang-gun
#
#                                                      geometry
# SIG_KOR_NM
# 춘천시         POLYGON ((127.58509 38.08062, 127.58474 38.080...
# 원주시         POLYGON ((127.93580 37.50246, 127.93525 37.502...
# 강릉시         MULTIPOLYGON (((129.04785 37.64961, 129.04781 ...
# 동해시         MULTIPOLYGON (((129.15821 37.47636, 129.15821 ...
# 태백시         POLYGON ((128.91030 37.06831, 128.91036 37.069...
# ...                                                       ...
# 증평군         POLYGON ((127.63781 36.84565, 127.63733 36.845...
# ...

# %%
m=folium.Map(location=[35.8,127.6], tiles="OpenStreetMap", zoom_start=8)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
locals=pd.read_csv("전국시군구위험도가제.csv", encoding='utf-8-sig')
locals
# Out:
#                주소           x          y                                 xy  \
# 0       서울특별시 종로구  126.978990  37.573504  126.978989954189,37.5735042429813
# 1        서울특별시 중구  126.997555  37.563808  126.997555182293,37.5638077703601
# 2       서울특별시 용산구  126.990582  37.532431  126.990582345331,37.5324310391314
# 3       서울특별시 성동구  127.036930  37.563427   127.036930141185,37.563427205337
# 4       서울특별시 광진구  127.082385  37.538558  127.082385189457,37.5385583136667
# ..            ...         ...        ...                                ...
# 202      경상남도 함양군  127.725161  35.520527  127.725160459865,35.5205271695153
# 203      경상남도 거창군  127.909503  35.686685   127.90950298922,35.6866846276583
# 204      경상남도 합천군  128.165791  35.566670  128.165790828628,35.5666703386375
# 205   제주특별자치도 제주시  126.531171  33.499534   126.531171087132,33.499534241198
# 206  제주특별자치도 서귀포시  126.559563  33.254065  126.559563466911,33.2540646255037
#
#      위험도
# 0      7
# 1      8
# 2     10
# 3      2
# ...

# %% [markdown]
# risk=locals['위험도']
# risk
# locla=locals['시군구']
# locla
# locla_risk= pd.concat([locla,risk] ,axis=1)
# locla_risk

# %%
import pandas as pd
import folium
import webbrowser
 
# Load the shape of the zone (US states)
# Find the original file here: https://github.com/python-visualization/folium/tree/master/examples/data
# You have to download this file and set the directory where you saved it
state_geo = 'SIG_202101/TL_SCCO_SIG20.shp'
 
# Load the unemployment value of each state
# Find the original file here: https://github.com/python-visualization/folium/tree/master/examples/data
state_unemployment = 'Total_People_2018.csv'
state_data = pd.read_csv(state_unemployment, encoding = 'euc-kr')
 
# Initialize the map:
m = folium.Map(location=[36, 127], tiles="OpenStreetMap", zoom_start=7)
 
# Add the color for the chloropleth:

m.choropleth(
 geo_data=state_geo,
 name='choropleth',
 data=state_data,
 columns=['Code','risk'],
 key_on='feature.properties.SIG_CD',
 fill_color='YlGn',
 fill_opacity=0.7,
 line_opacity=0.5,
 legend_name='Population Rate (%)'
)

folium.LayerControl().add_to(m)
 
# Save to html
m.save('folium_kr.html')
webbrowser.open_new("folium_kr.html")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\folium\folium.py:409: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %%
state_geo = 'TL_SCCO_SIG_WGS84.json'

# %%
state_unemployment = 'Total_People_2018.csv'
state_data = pd.read_csv(state_unemployment, encoding = 'euc-kr')
state_data.columns = ['CODE', 'POPULATION']
state_data['CODE'] = state_data.CODE.map(lambda x : str(x).zfill(5))
state_data.head(1)
# Out:
#      CODE  POPULATION
# 0  41190A    851012.0

# %%
# Initialize the map:
m = folium.Map(location=[36, 127], tiles="OpenStreetMap", zoom_start=7)

m.choropleth(
    geo_data=state_geo,
    name='인구수',
    data=state_data,
    columns=['CODE', 'POPULATION'],
    key_on='feature.properties.SIG_CD',
    fill_color='YlGn',
    fill_opacity=0.7,
    line_opacity=0.3,
    color = 'gray',
    legend_name = 'Population'
)

folium.LayerControl().add_to(m)

# Save to html
m.save('folium_kr.html')
webbrowser.open_new("folium_kr.html")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\folium\folium.py:409: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   warnings.warn(
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-17-e71d526b7474> in <module>
#       2 m = folium.Map(location=[36, 127], tiles="OpenStreetMap", zoom_start=7)
#       3
# ----> 4 m.choropleth(
#       5     geo_data=state_geo,
#       6     name='인구수',
#
# C:\ProgramData\Anaconda3\lib\site-packages\folium\folium.py in choropleth(self, *args, **kwargs)
#     414         )
#     415         from folium.features import Choropleth
# --> 416         self.add_child(Choropleth(*args, **kwargs))
#     417
#     418     def keep_in_front(self, *args):
#
# ...

# %%
folium.Choropleth(
    geo_data=state_geo,
    name="choropleth",
    data=state_data,
    columns=["State", "Unemployment"],
    key_on="feature.id",
    fill_color="YlGn",
    fill_opacity=0.7,
    line_opacity=.1,
    legend_name="Unemployment Rate (%)",
).add_to(m)

folium.LayerControl().add_to(m)

# %%
 # !pip install plotly

# %%
m = folium.Map(location=[36, 127], tiles="OpenStreetMap", zoom_start=7)

m.choropleth(
    geo_data=state_geo,
    name='인구수',
    data=state_data,
    columns=['CODE', 'POPULATION'],
    key_on='feature.properties.SIG_CD',
    fill_color='YlGn',
    fill_opacity=0.7,
    line_opacity=0.3,
    color = 'gray',
    legend_name = 'Population'
)

folium.LayerControl().add_to(m)

# Save to html
m.save('folium_kr.html')
webbrowser.open_new("folium_kr.html")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\folium\folium.py:409: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   warnings.warn(
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-48-b3bf7c1154e2> in <module>
#       1 m = folium.Map(location=[36, 127], tiles="OpenStreetMap", zoom_start=7)
#       2
# ----> 3 m.choropleth(
#       4     geo_data=state_geo,
#       5     name='인구수',
#
# C:\ProgramData\Anaconda3\lib\site-packages\folium\folium.py in choropleth(self, *args, **kwargs)
#     414         )
#     415         from folium.features import Choropleth
# --> 416         self.add_child(Choropleth(*args, **kwargs))
#     417
#     418     def keep_in_front(self, *args):
#
# ...

# %%
state_geo= gpd.GeoDataFrame.from_file('시각화_data/SIG2.json',encoding='cp949')

# %%
state_unemployment ='시군구코드_2019가제.csv'
state_data = pd.read_csv(state_unemployment) #encoding = 'euc-kr')
state_data.columns = ['CODE','시도명','시군구명','RISK']
state_data['CODE'] = state_data.CODE.map(lambda x : str(x).zfill(5))
state_data.head(1)
# Out:
#     CODE    시도명 시군구명  RISK
# 0  11110  서울특별시  종로구     9

# %%
#state_data['POPULATION']=2

# %%
state_data
# Out:
#       CODE      시도명  시군구명  RISK
# 0    11110    서울특별시   종로구     9
# 1    11140    서울특별시    중구    10
# 2    11170    서울특별시   용산구     8
# 3    11200    서울특별시   성동구     7
# 4    11215    서울특별시   광진구     6
# ..     ...      ...   ...   ...
# 245  48870     경상남도   함양군     9
# 246  48880     경상남도   거창군     9
# 247  48890     경상남도   합천군     9
# 248  50110  제주특별자치도   제주시     2
# 249  50130  제주특별자치도  서귀포시    10
#
# [250 rows x 4 columns]

# %%
m = folium.Map(location=[36, 127], tiles="OpenStreetMap", zoom_start=7)

m.choropleth(
    geo_data=state_geo,
    name='위험도',
    data=state_data,
    columns=['CODE', 'RISK'],
    key_on='feature.properties.SIG_CD',
    fill_color='YlGn',
    fill_opacity=0.7,
    line_opacity=0.3,
    color = 'gray',
    legend_name = 'RISK'
)

folium.LayerControl().add_to(m)

# Save to html
m.save('folium_kr.html')
webbrowser.open_new("folium_kr.html")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\folium\folium.py:409: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   warnings.warn(
# True
