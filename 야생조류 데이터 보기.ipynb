# %%
import pandas as pd
import numpy as np
import datetime
import pandas as pd
import seaborn as sns
import scipy as sp
from scipy import stats

# %%
# 2003-2021 년도 별 데이터 불러오기 
AI_birds_year=pd.read_csv("./data/wild_birds_year.csv")
wild_birds_year=AI_birds_year.copy()
wild_birds_year.head()
# Out:
#       구분     시도   시군    2003년      2004년      2005년      2006년      2007년  \
# 0   조사종수      -    -      188        176        171        185        188
# 1     합계      -    -  971,176  1,109,531  1,175,808  1,184,287  1,577,499
# 2   철원평야   강원도   철원군    2,977     12,994      4,025     17,521      5,176
# 3    연천군   경기도   연천군        0          0     14,809     13,017     13,534
# 4  성산-성수  서울특별시  성동구        0          0          0          0      6,230
#
#        2008년      2009년  ...      2013년      2014년    2015년      2016년  \
# 0        194        197  ...        206        206      180        194
# 1  1,459,277  1,914,446  ...  1,106,287  1,256,065  974,685  1,568,527
# 2      5,759     21,436  ...      4,177      5,489   10,857     17,208
# 3     15,252     18,588  ...     11,580      9,458    3,530      9,172
# 4      3,540      5,277  ...      7,727      8,706    6,333      2,527
#
#        2017년      2018년      2019년      2020년      2021년           평균
# ...

# %%
wild_birds_year
# Out:
#         구분     시도    시군    2003년      2004년      2005년      2006년      2007년  \
# 0     조사종수      -     -      188        176        171        185        188
# 1       합계      -     -  971,176  1,109,531  1,175,808  1,184,287  1,577,499
# 2     철원평야   강원도    철원군    2,977     12,994      4,025     17,521      5,176
# 3      연천군   경기도    연천군        0          0     14,809     13,017     13,534
# 4    성산-성수  서울특별시   성동구        0          0          0          0      6,230
# ..     ...    ...   ...      ...        ...        ...        ...        ...
# 244    논산천   충청남도   논산시        0          0          0          0          0
# 245     신천   경기도   동두천시        0          0          0          0          0
# 246   원천리천   경기도    수원시        0          0          0          0          0
# 247    원평천   전라북도   김제시        0          0          0          0          0
# 248  장척저수지   경상북도   창녕군        0          0          0          0          0
#
# ...

# %%
# 2014-2021 월 별 데이터 불러오기(10,11,12,1,2)
wild_birds_monthr=pd.read_csv("./data/wild_birds_month.csv")
wild_birds_monthr
# Out:
#         구분     시도    시군   14-Oct     14-Nov     14-Dec   15-Jan   15-Feb  \
# 0     조사종수      -     -      182        190        186      180      186
# 1       합계      -     -  617,312  1,038,700  1,111,763  974,685  675,607
# 2     철원평야   강원도    철원군   51,660     43,900      9,336   10,857   14,109
# 3      연천군   경기도    연천군      595      1,150      1,227    3,530    4,674
# 4    성산-성수  서울특별시   성동구      477      4,443      7,212    6,333    5,853
# ..     ...    ...   ...      ...        ...        ...      ...      ...
# 244    논산천   충청남도   논산시        0          0          0        0        0
# 245     신천   경기도   동두천시        0          0          0        0        0
# 246   원천리천   경기도    수원시        0          0          0        0        0
# 247    원평천   전라북도   김제시        0          0          0        0        0
# 248  장척저수지   경상북도   창녕군        0          0          0        0        0
#
#       15-Mar   15-Oct  ...     20-Jan   20-Feb   20-Mar   20-Oct   20-Nov  \
# ...
