# %%
pip install pydeck
# Out:
# Collecting pydeck
#   Downloading pydeck-0.7.0-py2.py3-none-any.whl (4.3 MB)
# Requirement already satisfied: ipykernel>=5.1.2 in c:\users\user\.conda\envs\my_env\lib\site-packages (from pydeck) (5.3.4)
# Requirement already satisfied: traitlets>=4.3.2 in c:\users\user\.conda\envs\my_env\lib\site-packages (from pydeck) (5.0.5)
# Requirement already satisfied: numpy>=1.16.4 in c:\users\user\.conda\envs\my_env\lib\site-packages (from pydeck) (1.19.2)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\user\.conda\envs\my_env\lib\site-packages (from pydeck) (7.5.1)
# Requirement already satisfied: jinja2>=2.10.1 in c:\users\user\.conda\envs\my_env\lib\site-packages (from pydeck) (2.11.2)
# Requirement already satisfied: jupyter-client in c:\users\user\.conda\envs\my_env\lib\site-packages (from ipykernel>=5.1.2->pydeck) (6.1.7)
# Requirement already satisfied: ipython>=5.0.0 in c:\users\user\.conda\envs\my_env\lib\site-packages (from ipykernel>=5.1.2->pydeck) (7.19.0)
# Requirement already satisfied: tornado>=4.2 in c:\users\user\.conda\envs\my_env\lib\site-packages (from ipykernel>=5.1.2->pydeck) (6.0.4)
# Requirement already satisfied: pygments in c:\users\user\.conda\envs\my_env\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck) (2.7.2)
# Requirement already satisfied: colorama in c:\users\user\.conda\envs\my_env\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck) (0.4.4)
# Requirement already satisfied: pickleshare in c:\users\user\.conda\envs\my_env\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\user\.conda\envs\my_env\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck) (3.0.8)
# Requirement already satisfied: jedi>=0.10 in c:\users\user\.conda\envs\my_env\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck) (0.17.1)
# Requirement already satisfied: setuptools>=18.5 in c:\users\user\.conda\envs\my_env\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck) (50.3.1.post20201107)
# Requirement already satisfied: backcall in c:\users\user\.conda\envs\my_env\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck) (0.2.0)
# Requirement already satisfied: decorator in c:\users\user\.conda\envs\my_env\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck) (4.4.2)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\user\.conda\envs\my_env\lib\site-packages (from ipywidgets>=7.0.0->pydeck) (5.0.8)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\user\.conda\envs\my_env\lib\site-packages (from ipywidgets>=7.0.0->pydeck) (3.5.1)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\user\.conda\envs\my_env\lib\site-packages (from jedi>=0.10->ipython>=5.0.0->ipykernel>=5.1.2->pydeck) (0.7.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\user\.conda\envs\my_env\lib\site-packages (from jinja2>=2.10.1->pydeck) (1.1.1)
# Requirement already satisfied: ipython-genutils in c:\users\user\.conda\envs\my_env\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->pydeck) (0.2.0)
# Requirement already satisfied: jupyter-core in c:\users\user\.conda\envs\my_env\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->pydeck) (4.6.3)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\user\.conda\envs\my_env\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->pydeck) (3.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\user\.conda\envs\my_env\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->pydeck) (0.17.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\user\.conda\envs\my_env\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->pydeck) (20.3.0)
# Requirement already satisfied: six>=1.11.0 in c:\users\user\.conda\envs\my_env\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->pydeck) (1.15.0)
# Requirement already satisfied: wcwidth in c:\users\user\.conda\envs\my_env\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.0.0->ipykernel>=5.1.2->pydeck) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\user\.conda\envs\my_env\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck) (6.1.4)
# Requirement already satisfied: Send2Trash in c:\users\user\.conda\envs\my_env\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck) (1.5.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\user\.conda\envs\my_env\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck) (0.9.1)
# Requirement already satisfied: prometheus-client in c:\users\user\.conda\envs\my_env\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck) (0.8.0)
# Requirement already satisfied: pyzmq>=17 in c:\users\user\.conda\envs\my_env\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck) (19.0.2)
# Requirement already satisfied: nbconvert in c:\users\user\.conda\envs\my_env\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck) (6.0.7)
# Requirement already satisfied: argon2-cffi in c:\users\user\.conda\envs\my_env\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck) (20.1.0)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\user\.conda\envs\my_env\lib\site-packages (from jupyter-client->ipykernel>=5.1.2->pydeck) (2.8.1)
# Requirement already satisfied: pywin32>=1.0 in c:\users\user\.conda\envs\my_env\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets>=7.0.0->pydeck) (227)
# Requirement already satisfied: pywinpty>=0.5 in c:\users\user\.conda\envs\my_env\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck) (0.5.7)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\user\.conda\envs\my_env\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck) (1.14.3)
# Requirement already satisfied: pycparser in c:\users\user\.conda\envs\my_env\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck) (2.20)
# Requirement already satisfied: jupyterlab-pygments in c:\users\user\.conda\envs\my_env\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck) (0.1.2)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\user\.conda\envs\my_env\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck) (0.5.1)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\user\.conda\envs\my_env\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck) (0.3)
# Requirement already satisfied: bleach in c:\users\user\.conda\envs\my_env\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck) (3.2.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\user\.conda\envs\my_env\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\user\.conda\envs\my_env\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck) (1.4.3)
# Requirement already satisfied: defusedxml in c:\users\user\.conda\envs\my_env\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck) (0.6.0)
# Requirement already satisfied: testpath in c:\users\user\.conda\envs\my_env\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck) (0.4.4)
# Requirement already satisfied: nest-asyncio in c:\users\user\.conda\envs\my_env\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck) (1.4.2)
# Requirement already satisfied: async-generator in c:\users\user\.conda\envs\my_env\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck) (1.10)
# Requirement already satisfied: packaging in c:\users\user\.conda\envs\my_env\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck) (20.4)
# Requirement already satisfied: webencodings in c:\users\user\.conda\envs\my_env\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck) (0.5.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\user\.conda\envs\my_env\lib\site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck) (2.4.7)
# Installing collected packages: pydeck
# Successfully installed pydeck-0.7.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -5py (c:\users\user\.conda\envs\my_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -5py (c:\users\user\.conda\envs\my_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -5py (c:\users\user\.conda\envs\my_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -5py (c:\users\user\.conda\envs\my_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -5py (c:\users\user\.conda\envs\my_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -5py (c:\users\user\.conda\envs\my_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -5py (c:\users\user\.conda\envs\my_env\lib\site-packages)
# WARNING: You are using pip version 21.1.2; however, version 21.2.4 is available.
# You should consider upgrading via the 'C:\Users\user\.conda\envs\my_env\python.exe -m pip install --upgrade pip' command.

# %%
import pydeck as pdk

# %%
import geopandas as gpd
import pandas as pd
import matplotlib as mpl
import folium
import webbrowser
from folium import plugins
import matplotlib.pyplot as plt
from shapely.geometry import Point, Polygon, LineString
import matplotlib.font_manager as fm

font_name = fm.FontProperties(fname='C:/Windows/Fonts/H2GSRB.TTF').get_name()
mpl.rc('font', family=font_name)

# %%
pip install folium
# Out:
# Collecting folium
#   Downloading folium-0.12.1-py2.py3-none-any.whl (94 kB)
# Requirement already satisfied: numpy in c:\users\user\.conda\envs\my_env\lib\site-packages (from folium) (1.19.2)
# Requirement already satisfied: requests in c:\users\user\.conda\envs\my_env\lib\site-packages (from folium) (2.24.0)
# Collecting branca>=0.3.0
#   Downloading branca-0.4.2-py3-none-any.whl (24 kB)
# Requirement already satisfied: jinja2>=2.9 in c:\users\user\.conda\envs\my_env\lib\site-packages (from folium) (2.11.2)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\user\.conda\envs\my_env\lib\site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\.conda\envs\my_env\lib\site-packages (from requests->folium) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\user\.conda\envs\my_env\lib\site-packages (from requests->folium) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\user\.conda\envs\my_env\lib\site-packages (from requests->folium) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\user\.conda\envs\my_env\lib\site-packages (from requests->folium) (3.0.4)
# Installing collected packages: branca, folium
# Note: you may need to restart the kernel to use updated packages.Successfully installed branca-0.4.2 folium-0.12.1
# WARNING: Ignoring invalid distribution -5py (c:\users\user\.conda\envs\my_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -5py (c:\users\user\.conda\envs\my_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -5py (c:\users\user\.conda\envs\my_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -5py (c:\users\user\.conda\envs\my_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -5py (c:\users\user\.conda\envs\my_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -5py (c:\users\user\.conda\envs\my_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -5py (c:\users\user\.conda\envs\my_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -5py (c:\users\user\.conda\envs\my_env\lib\site-packages)
# WARNING: You are using pip version 21.1.2; however, version 21.2.4 is available.
# You should consider upgrading via the 'C:\Users\user\.conda\envs\my_env\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd

korea= gpd.GeoDataFrame.from_file('시군구/SIG2.shp', encoding='cp949')

# %%
mm=folium.Map(location=[35.8,127.6], tiles="OpenStreetMap", zoom_start=8)
mm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_ca37938994af44d890e9e5e64d1100a3%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_ca37938994af44d890e9e5e64d1100a3%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_ca37938994af44d890e9e5e64d1100a3%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_ca37938994af44d890e9e5e64d1100a3%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B35.8%2C%20127.6%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20c ...

# %%
#전국 시군구 geo
korea
# Out:
#     SIG_CD       SIG_ENG_NM SIG_KOR_NM  \
# 0    42110     Chuncheon-si        춘천시
# 1    42130         Wonju-si        원주시
# 2    42150     Gangneung-si        강릉시
# 3    42170       Donghae-si        동해시
# 4    42190       Taebaek-si        태백시
# ..     ...              ...        ...
# 245  43745  Jeungpyeong-gun        증평군
# 246  43750     Jincheon-gun        진천군
# 247  43760       Goesan-gun        괴산군
# 248  43770     Eumseong-gun        음성군
# 249  43800      Danyang-gun        단양군
#
#                                               geometry
# 0    POLYGON ((127.58509 38.08062, 127.58566 38.080...
# 1    POLYGON ((127.93580 37.50246, 127.93618 37.502...
# 2    MULTIPOLYGON (((129.04785 37.64961, 129.04788 ...
# 3    MULTIPOLYGON (((129.08794 37.59500, 129.08789 ...
# 4    POLYGON ((129.01252 37.33636, 129.01245 37.336...
# ..                                                 ...
# 245  POLYGON ((127.53733 36.80859, 127.53797 36.808...
# 246  POLYGON ((127.44138 37.01190, 127.44193 37.011...
# 247  POLYGON ((127.80067 36.94755, 127.80079 36.947...
# 248  POLYGON ((127.62988 37.15424, 127.62987 37.154...
# 249  POLYGON ((128.33887 37.15780, 128.33896 37.157...
#
# [250 rows x 4 columns]

# %%
#AI발생지 불러오기
local3= pd.read_csv('전국 발생지(0908).csv', dtype=str)
local3.head(2)
# Out:
#   SIG_CD   시도  시군구  월            x            y  \
# 0  42810  강원도  인제군  1  128.1703515  38.06970974
# 1  42730  강원도  횡성군  1    127.98508  37.49178316
#
#                                   xy
# 0   128.170351505777,38.069709741838
# 1  127.985079956092,37.4917831601354

# %%
#전국 시군구 json불러오기
dd = gpd.read_file('시군구/SIG2.json')

# %%
dd.head(2)
# Out:
#   SIG_CD    SIG_ENG_NM SIG_KOR_NM  \
# 0  42110  Chuncheon-si        춘천시
# 1  42130      Wonju-si        원주시
#
#                                             geometry
# 0  POLYGON ((127.58509 38.08062, 127.58474 38.080...
# 1  POLYGON ((127.93580 37.50246, 127.93525 37.502...

# %%
#dd geometry 좌표 확인
dd.geometry.centroid
# Out:
# <ipython-input-18-35d423d6f184>:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   dd.geometry.centroid
# 0      POINT (127.73995 37.88985)
# 1      POINT (127.92954 37.30826)
# 2      POINT (128.83222 37.70920)
# 3      POINT (129.05564 37.50673)
# 4      POINT (128.98006 37.17237)
#                   ...
# 245    POINT (127.60460 36.78649)
# 246    POINT (127.44043 36.87102)
# 247    POINT (127.82958 36.76969)
# 248    POINT (127.61418 36.97626)
# 249    POINT (128.38789 36.99451)
# Length: 250, dtype: geometry

# %%
dd.geometry[0].boundary

# %%
dd.geometry[1].boundary

# %%
#전국 AI발생지 x,y를 geo화 하기
local33 = gpd.GeoDataFrame(local3, geometry=gpd.points_from_xy(local2.x,local2.y))
print(local33.head())
# Out:
#   SIG_CD   시도   시군구  월            x            y  \
# 0  42810  강원도   인제군  1  128.1703515  38.06970974
# 1  42730  강원도   횡성군  1    127.98508  37.49178316
# 2  41610  경기도   광주시  1  127.2551387  37.42939419
# 3  41570  경기도   김포시  1  126.7156579  37.61526869
# 4  41360  경기도  남양주시  1  127.2164803  37.63602723
#
#                                   xy                    geometry
# 0   128.170351505777,38.069709741838  POINT (128.17035 38.06971)
# 1  127.985079956092,37.4917831601354  POINT (127.98508 37.49178)
# 2  127.255138719721,37.4293941934866  POINT (127.25514 37.42939)
# 3  126.715657922927,37.6152686898333  POINT (126.71566 37.61527)
# 4   127.21648030719,37.6360272346499  POINT (127.21648 37.63603)

# %%
local33
# Out:
#     SIG_CD    시도   시군구   월            x            y  \
# 0    42810   강원도   인제군   1  128.1703515  38.06970974
# 1    42730   강원도   횡성군   1    127.98508  37.49178316
# 2    41610   경기도   광주시   1  127.2551387  37.42939419
# 3    41570   경기도   김포시   1  126.7156579  37.61526869
# 4    41360   경기도  남양주시   1  127.2164803  37.63602723
# ..     ...   ...   ...  ..          ...          ...
# 102  46880  전라남도   장성군  12  126.7849189  35.30185768
# 103  46900  전라남도   진도군  12  126.2634462  34.48682862
# 104  45190  전라북도   남원시  12  127.3903964  35.41636275
# 105  44810  충청남도   예산군  12  126.8486422   36.6826228
# 106  43730  충청북도   옥천군  12   127.571345  36.30643556
#
#                                     xy                    geometry
# 0     128.170351505777,38.069709741838  POINT (128.17035 38.06971)
# 1    127.985079956092,37.4917831601354  POINT (127.98508 37.49178)
# 2    127.255138719721,37.4293941934866  POINT (127.25514 37.42939)
# 3    126.715657922927,37.6152686898333  POINT (126.71566 37.61527)
# 4     127.21648030719,37.6360272346499  POINT (127.21648 37.63603)
# ..                                 ...                         ...
# 102  126.784918877012,35.3018576771354  POINT (126.78492 35.30186)
# 103   126.263446186439,34.486828620348  POINT (126.26345 34.48683)
# 104  127.390396427422,35.4163627529983  POINT (127.39040 35.41636)
# 105  126.848642241312,36.6826228017861  POINT (126.84864 36.68262)
# 106  127.571345042936,36.3064355612681  POINT (127.57134 36.30644)
#
# [107 rows x 8 columns]

# %%
local33.to_csv('local33.csv', encoding='cp949')

# %%
#전국 시군구와 전국 발생지 좌표계 확인 후 좌표 맞춰주기

# %%
print(local33.crs)
# Out:
# None

# %%
print(local33.columns)
# Out:
# Index(['SIG_CD', '시도', '시군구', '월', 'x', 'y', 'xy', 'geometry'], dtype='object')

# %%
print(dd2.crs)
# Out:
# epsg:3857

# %%
local33.crs = 'epsg:4326'

# %%
dd2 = dd2.to_crs('epsg:3857')

# %%
local33 = local33.to_crs('epsg:3857')

# %%
print(local33.crs)
# Out:
# epsg:3857

# %%
local22.crs = 'epsg:4326'
dd2 = dd2.to_crs('epsg:3857')

print(dd2.crs)
# Out:
# epsg:3857

# %%
print(dd2.geometry.area.head())
# Out:
# 0    1.794024e+09
# 1    1.372789e+09
# 2    1.662538e+09
# 3    2.875825e+08
# 4    4.786251e+08
# dtype: float64

# %%
dd2
# Out:
#     SIG_CD       SIG_ENG_NM SIG_KOR_NM  \
# 0    42110     Chuncheon-si        춘천시
# 1    42130         Wonju-si        원주시
# 2    42150     Gangneung-si        강릉시
# 3    42170       Donghae-si        동해시
# 4    42190       Taebaek-si        태백시
# ..     ...              ...        ...
# 245  43745  Jeungpyeong-gun        증평군
# 246  43750     Jincheon-gun        진천군
# 247  43760       Goesan-gun        괴산군
# 248  43770     Eumseong-gun        음성군
# 249  43800      Danyang-gun        단양군
#
#                                               geometry
# 0    POLYGON ((14202706.752 4590821.443, 14202668.5...
# 1    POLYGON ((14241748.069 4509376.262, 14241687.3...
# 2    MULTIPOLYGON (((14365541.457 4530044.682, 1436...
# 3    MULTIPOLYGON (((14377826.006 4505715.415, 1437...
# 4    POLYGON ((14350228.692 4448632.944, 14350235.2...
# ..                                                 ...
# 245  POLYGON ((14208576.168 4417614.033, 14208523.0...
# 246  POLYGON ((14187345.000 4440624.198, 14187344.8...
# 247  POLYGON ((14226705.267 4431798.961, 14226633.0...
# 248  POLYGON ((14201948.945 4418742.961, 14201948.9...
# 249  POLYGON ((14286685.801 4461152.118, 14286682.3...
#
# [250 rows x 4 columns]

# %%
dd2.to_csv('dd2.csv',encoding='cp949')

# %%
#전국 시군구 지도
ax = dd2.plot(column='SIG_KOR_NM', figsize=(20,20), alpha=1.0)

# %%
#전국 시군구에 발생지 표시하기
ax = dd2.plot(column='SIG_KOR_NM', figsize=(20,20), alpha=0.8)
local33.plot(ax=ax, marker='v', color='black', label='발생지')
ax.set_title("전국 발생지", fontsize=20)
ax.set_axis_off()
plt.legend()

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
m = folium.Map(location=[36,127], tiles='OpenStreetMap', zoom_start=7)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_aa43a85c71b8442b9ed29fc847347165%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_aa43a85c71b8442b9ed29fc847347165%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_aa43a85c71b8442b9ed29fc847347165%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_aa43a85c71b8442b9ed29fc847347165%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B36.0%2C%20127.0%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20c ...

# %%
m.choropleth(
    geo_data=local33,
    name='발생지',
    data=local33,
    columns=['SIG_CD', '월'],
    fill_color='YlGn',
    fill_opacity=0.7,
    line_opacity=0.3,
    color = 'gray',
    legend_name = '발생지'
)

folium.LayerControl().add_to(m)

m.save('folium_kr.html')
webbrowser.open_new("folium_kr.html")
# Out:
# True

# %%
#발생지 월별 시각화(하려던 파일 아직 생성못해서 이걸로 일단 되는지 봄)
#전국 시군구에 행정구역코드, 위험도 같이 들어있는 파일 있으면 될 듯

# %%
#행정구역 파일 가져오기
state_geo = gpd.GeoDataFrame.from_file('시군구/SIG2.json')

# %%
state_geo
# Out:
#     SIG_CD       SIG_ENG_NM SIG_KOR_NM  \
# 0    42110     Chuncheon-si        춘천시
# 1    42130         Wonju-si        원주시
# 2    42150     Gangneung-si        강릉시
# 3    42170       Donghae-si        동해시
# 4    42190       Taebaek-si        태백시
# ..     ...              ...        ...
# 245  43745  Jeungpyeong-gun        증평군
# 246  43750     Jincheon-gun        진천군
# 247  43760       Goesan-gun        괴산군
# 248  43770     Eumseong-gun        음성군
# 249  43800      Danyang-gun        단양군
#
#                                               geometry
# 0    POLYGON ((127.58509 38.08062, 127.58474 38.080...
# 1    POLYGON ((127.93580 37.50246, 127.93525 37.502...
# 2    MULTIPOLYGON (((129.04785 37.64961, 129.04781 ...
# 3    MULTIPOLYGON (((129.15821 37.47636, 129.15821 ...
# 4    POLYGON ((128.91030 37.06831, 128.91036 37.069...
# ..                                                 ...
# 245  POLYGON ((127.63781 36.84565, 127.63733 36.845...
# 246  POLYGON ((127.44709 37.01089, 127.44709 37.010...
# 247  POLYGON ((127.80067 36.94755, 127.80002 36.947...
# 248  POLYGON ((127.57828 36.85376, 127.57828 36.853...
# 249  POLYGON ((128.33948 37.15799, 128.33945 37.157...
#
# [250 rows x 4 columns]

# %%
#발생지 데이터 로드
state_data = pd.read_csv('local33.csv', encoding='euc-kr')
state_data
# Out:
#      Unnamed: 0  SIG_CD    시도   시군구   월           x          y  \
# 0             0   42810   강원도   인제군   1  128.170351  38.069710
# 1             1   42730   강원도   횡성군   1  127.985080  37.491783
# 2             2   41610   경기도   광주시   1  127.255139  37.429394
# 3             3   41570   경기도   김포시   1  126.715658  37.615269
# 4             4   41360   경기도  남양주시   1  127.216480  37.636027
# ..          ...     ...   ...   ...  ..         ...        ...
# 102         102   46880  전라남도   장성군  12  126.784919  35.301858
# 103         103   46900  전라남도   진도군  12  126.263446  34.486829
# 104         104   45190  전라북도   남원시  12  127.390396  35.416363
# 105         105   44810  충청남도   예산군  12  126.848642  36.682623
# 106         106   43730  충청북도   옥천군  12  127.571345  36.306436
#
#                                     xy  \
# 0     128.170351505777,38.069709741838
# 1    127.985079956092,37.4917831601354
# 2    127.255138719721,37.4293941934866
# 3    126.715657922927,37.6152686898333
# 4     127.21648030719,37.6360272346499
# ..                                 ...
# 102  126.784918877012,35.3018576771354
# 103   126.263446186439,34.486828620348
# 104  127.390396427422,35.4163627529983
# 105  126.848642241312,36.6826228017861
# 106  127.571345042936,36.3064355612681
#
#                                         geometry
# 0    POINT (14267858.26377489 4589278.146975644)
# 1    POINT (14247233.93473638 4507878.509390133)
# 2      POINT (14165977.2409114 4499129.00695324)
# 3    POINT (14105922.51296265 4525217.844124892)
# 4    POINT (14161673.80750852 4528135.498380336)
# ..                                           ...
# 102  POINT (14113632.61221449 4204978.437580858)
# 103  POINT (14055582.53678789 4094360.046487946)
# 104  POINT (14181034.05920127 4220608.124332487)
# 105  POINT (14120726.25752215 4394960.345832366)
# 106  POINT (14201177.16521303 4342868.769322217)
#
# [107 rows x 9 columns]

# %%
#필요없는 컬럼 삭제하고, 코드번호 숫자 인식돼서 오류 생기지 않게 zfill처리 함
state_data = state_data.drop(['Unnamed: 0','geometry','시도','시군구','x','y','xy'], axis=1)
state_data.columns=['SIG_CD', '월']
state_data['SIG_CD'] = state_data.SIG_CD.map(lambda x: str(x).zfill(5))
state_data.head(1)
# Out:
#   SIG_CD  월
# 0  42810  1

# %%
m = folium.Map(location=[36,127], tiles='OpenStreetMap', zoom_start=7)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_b6accb83a7db4b1abaaf135fb139ae32%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_b6accb83a7db4b1abaaf135fb139ae32%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_b6accb83a7db4b1abaaf135fb139ae32%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_b6accb83a7db4b1abaaf135fb139ae32%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B36.0%2C%20127.0%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20c ...

# %%
#https://plotly.com/python/builtin-colorscales/
#컬러 볼 수 있는 사이트

# %%
#색깔로 표시하기
m.choropleth(
    geo_data=state_geo,
    name='발생지',
    data=state_data,
    columns=['SIG_CD', '월'],
    key_on='feature.properties.SIG_CD',
    fill_color='RdBu',
    fill_opacity=0.7,
    line_opacity=0.3,
    color = 'gray',
    legend_name = '발생지/월별'
)

folium.LayerControl().add_to(m)

# Save to html
m.save('folium_kr.html')
webbrowser.open_new("folium_kr.html")
# Out:
# True
